# %%
import pandas as pd
data=pd.read_csv("data.csv")
print(data)
# Out:
#    student_id            name  year   gpa
# 0        S001     Alice Kumar     3  2.68
# 1        S002    Ayesha Silva     1  2.48
# 2        S003   Ayesha Wilson     1  2.65
# 3        S004   Michael Brown     3  2.95
# 4        S005     Sarah Brown     1  3.13
# ..        ...             ...   ...   ...
# 95       S096   Ethan Johnson     3  2.47
# 96       S097  Nimal Fernando     1  3.23
# 97       S098    Liam Johnson     3  3.92
# 98       S099   John Anderson     3  3.60
# 99       S100  Michael Perera     4  3.48
#
# [100 rows x 4 columns]

# %%
data.describe(include="all")
# Out:
#                 name        year         gpa
# count            100  100.000000  100.000000
# unique            86         NaN         NaN
# top     David Taylor         NaN         NaN
# freq               3         NaN         NaN
# mean             NaN    2.560000    2.958600
# std              NaN    1.113008    0.585981
# min              NaN    1.000000    2.020000
# 25%              NaN    2.000000    2.477500
# 50%              NaN    3.000000    2.910000
# 75%              NaN    4.000000    3.482500
# max              NaN    4.000000    3.990000

# %%
print(data["year"].unique())
# Out:
# [3 1 4 2]

# %%
print(data[data["gpa"]>=3].index)
# Out:
# Index(['S005', 'S008', 'S011', 'S012', 'S014', 'S019', 'S021', 'S023', 'S026',
#        'S031', 'S032', 'S033', 'S036', 'S037', 'S038', 'S039', 'S041', 'S043',
#        'S044', 'S045', 'S047', 'S052', 'S053', 'S054', 'S055', 'S065', 'S066',
#        'S067', 'S068', 'S069', 'S072', 'S073', 'S078', 'S079', 'S080', 'S084',
#        'S085', 'S089', 'S091', 'S093', 'S094', 'S097', 'S098', 'S099', 'S100'],
#       dtype='object', name='student_id')

# %%
print (data.groupby("year").name.count())
# Out:
# year
# 1    23
# 2    24
# 3    27
# 4    26
# Name: name, dtype: int64

# %%
data=data["student_id"].
