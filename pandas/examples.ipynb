# %%
import pandas as pd
student_details=pd.read_csv("data.csv",sep=",")

# %%
student_details.shape
# Out:
# (100, 4)

# %%
student_details.isnull().sum()
# Out:
# student_id    0
# name          0
# year          0
# gpa           0
# dtype: int64
